# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,4*np.pi,0.1)
y=np.sin(x)
z=np.cos(x)
plt.plot(x,y)
plt.plot(x,z)
plt.show()

# %%
print("welcome to doggo")
print("0----/")
print("||||")
age=input("When where you born ???\n")
print("If you were a dog, your age would have been")
# Out:
# welcome to doggo
# 0----/
# ||||
# When where you born ???
# 2001
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-5bc454aabc29> in <module>
#       3 print("||||")
#       4 age=input("When where you born ???\n")
# ----> 5 print("If you were a dog, your age would have been",2020-age)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(-20,20)
y=x**2
plt.plot(x,y)
plt.show()
